# %% [markdown]
# # Data Exploration\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
from src.data.loader import load_training_data

# %%
df = load_training_data(sample_size=10000)

# %%
df.shape, df['isFraud'].mean(), df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# ((10000, 25),
#  np.float64(0.0265),
#  R_emaildomain    0.8375
#  DeviceInfo       0.8162
#  id_31            0.7885
#  DeviceType       0.7881
#  id_02            0.7881
#  id_01            0.7840
#  dist1            0.6615
#  D2               0.4577
#  P_emaildomain    0.2105
#  addr1            0.0913
#  addr2            0.0913
#  card2            0.0119
#  card5            0.0022
#  card6            0.0001
#  card4            0.0001
#  dtype: float64)
