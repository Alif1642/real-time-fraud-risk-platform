# %% [markdown]
# # Gradient Boosting\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
from src.models.train import train_project

# %%
metadata=train_project(model_names=['lightgbm','xgboost'], sample_size=50000)
# Out:
# 2026-09-01 19:57:44,495 | INFO | src.models.train | Loading REAL IEEE-CIS training data (debug sample)
# 2026-09-01 19:57:49,064 | INFO | src.models.train | Training lightgbm
# 2026-09-01 19:57:54,802 | WARNING | src.models.train | MLflow logging skipped/unavailable: The filesystem tracking backend (e.g., './mlruns') is in maintenance mode and will not receive further updates. Please migrate to a database backend (e.g., 'sqlite:///mlflow.db') to access the latest MLflow features. The `mlflow migrate-filestore` tool migrates your existing data losslessly. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance. If the filesystem backend is required for your workflow, set `MLFLOW_ALLOW_FILE_STORE=true` to opt out of this exception.
# 2026-09-01 19:57:55,034 | INFO | src.models.train | Training xgboost
# 2026-09-01 19:57:57,733 | WARNING | src.models.train | MLflow logging skipped/unavailable: The filesystem tracking backend (e.g., './mlruns') is in maintenance mode and will not receive further updates. Please migrate to a database backend (e.g., 'sqlite:///mlflow.db') to access the latest MLflow features. The `mlflow migrate-filestore` tool migrates your existing data losslessly. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance. If the filesystem backend is required for your workflow, set `MLFLOW_ALLOW_FILE_STORE=true` to opt out of this exception.
# 2026-09-01 19:58:03,164 | WARNING | src.models.train | MLflow logging skipped/unavailable: The filesystem tracking backend (e.g., './mlruns') is in maintenance mode and will not receive further updates. Please migrate to a database backend (e.g., 'sqlite:///mlflow.db') to access the latest MLflow features. The `mlflow migrate-filestore` tool migrates your existing data losslessly. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance. If the filesystem backend is required for your workflow, set `MLFLOW_ALLOW_FILE_STORE=true` to opt out of this exception.
# 2026-09-01 19:58:03,171 | INFO | src.models.train | Selected xgboost with validation-only threshold 0.480000

# %%
metadata
# Out:
# {'model_name': 'xgboost',
#  'model_version': 'xgboost_v1',
#  'result_label': 'LOCAL IEEE-CIS HOLDOUT RESULTS',
#  'training_timestamp_utc': '2026-09-01T13:58:02.165879+00:00',
#  'selection_metric': 'validation_pr_auc',
#  'calibration_method': 'sigmoid',
#  'calibration_selection_brier_scores': {'identity': 0.11719183286116347,
#   'sigmoid': 0.017603754217625937,
#   'isotonic': 0.018397277184979025},
#  'threshold': 0.48,
#  'validation_metrics': {'pr_auc': 0.3516983946937578,
#   'roc_auc': 0.8982890557498966,
#   'precision': 0.7,
#   'recall': 0.12612612612612611,
#   'fraud_capture_rate': 0.12612612612612611,
#   'f1': 0.21374045801526717,
#   'false_positive_rate': 0.0016488046166529267,
#   'brier_score': 0.023309161963914887,
#   'threshold': 0.48,
#   'tn': 3633,
#   'fp': 6,
#   'fn': 97,
#   'tp': 14,
#   'fixed_fpr': 0.01,
#   'fixed_fpr_threshold': 0.27121520720073167,
#   'recall_at_fixed_fpr': 0.25225225225225223,
#   'precision_at_fixed_fpr': 0.4444444444444444,
#   'business_cost': 44700.0,
#   'train_seconds': 2.094441799999913},
#  'test_metrics': {'pr_auc': 0.1914579643004192,
#   'roc_auc': 0.865771716390175,
#   'precision': 0.4074074074074074,
#   'recall': 0.07692307692307693,
#   'fraud_capture_rate': 0.07692307692307693,
#   'f1': 0.12941176470588237,
#   'false_positive_rate': 0.00217479951067011,
#   'brier_score': 0.017202195243450652,
#   'threshold': 0.48,
#   'tn': 7341,
#   'fp': 16,
#   'fn': 132,
#   'tp': 11,
#   'fixed_fpr': 0.01,
#   'fixed_fpr_threshold': 0.27265530974552826,
#   'recall_at_fixed_fpr': 0.17482517482517482,
#   'precision_at_fixed_fpr': 0.25773195876288657,
#   'business_cost_at_validation_threshold': 60450.0},
#  'dataset': {'mode': 'ieee_cis_sample',
#   'loaded_shape': [50000, 25],
#   'fraud_count': 1357,
#   'fraud_rate': 0.02714,
#   'duplicate_transaction_ids': 0,
#   'missing_target': 0,
#   'missing_rate': 0.2272768,
#   'infinite_numeric_values': 0,
#   'selected_raw_columns': ['TransactionID',
#    'isFraud',
#    'TransactionDT',
#    'TransactionAmt',
#    'ProductCD',
#    'card1',
#    'card2',
#    'card3',
#    'card4',
#    'card5',
#    'card6',
#    'addr1',
#    'addr2',
#    'dist1',
#    'P_emaildomain',
#    'R_emaildomain',
#    'C1',
#    'C2',
#    'D1',
#    'D2',
#    'id_01',
#    'id_02',
#    'id_31',
#    'DeviceType',
#    'DeviceInfo'],
#   'raw_file_inventory': {'train_transaction.csv': {'exists': True,
#     'size_bytes': 683351067,
#     'rows': 590540,
#     'columns': 394,
#     'has_transaction_id': True,
#     'has_target': True,
#     'normalized_identity_schema': None},
#    'train_identity.csv': {'exists': True,
#     'size_bytes': 26529680,
#     'rows': 144233,
#     'columns': 41,
#     'has_transaction_id': True,
#     'has_target': False,
#     'normalized_identity_schema': ['TransactionID',
#      'id_01',
#      'id_02',
#      'id_03',
#      'id_04',
#      'id_05',
#      'id_06',
#      'id_07',
#      'id_08',
#      'id_09',
#      'id_10',
#      'id_11',
#      'id_12',
#      'id_13',
#      'id_14',
#      'id_15',
#      'id_16',
#      'id_17',
#      'id_18',
#      'id_19',
#      'id_20',
#      'id_21',
#      'id_22',
#      'id_23',
#      'id_24',
#      'id_25',
#      'id_26',
#      'id_27',
#      'id_28',
#      'id_29',
#      'id_30',
#      'id_31',
#      'id_32',
#      'id_33',
#      'id_34',
#      'id_35',
#      'id_36',
#      'id_37',
#      'id_38',
#      'DeviceType',
#      'DeviceInfo']},
#    'test_transaction.csv': {'exists': True,
#     'size_bytes': 613194934,
#     'rows': 506691,
#     'columns': 393,
#     'has_transaction_id': True,
#     'has_target': False,
#     'normalized_identity_schema': None},
#    'test_identity.csv': {'exists': True,
#     'size_bytes': 25797161,
#     'rows': 141907,
#     'columns': 41,
#     'has_transaction_id': True,
#     'has_target': False,
#     'normalized_identity_schema': ['TransactionID',
#      'id_01',
#      'id_02',
#      'id_03',
#      'id_04',
#      'id_05',
#      'id_06',
#      'id_07',
#      'id_08',
#      'id_09',
#      'id_10',
#      'id_11',
#      'id_12',
#      'id_13',
#      'id_14',
#      'id_15',
#      'id_16',
#      'id_17',
#      'id_18',
#      'id_19',
#      'id_20',
#      'id_21',
#      'id_22',
#      'id_23',
#      'id_24',
#      'id_25',
#      'id_26',
#      'id_27',
#      'id_28',
#      'id_29',
#      'id_30',
#      'id_31',
#      'id_32',
#      'id_33',
#      'id_34',
#      'id_35',
#      'id_36',
#      'id_37',
#      'id_38',
#      'DeviceType',
#      'DeviceInfo']}},
#   'schema_consistency': {'checked': True,
#    'official_test_has_target': False,
#    'transaction_columns_match_after_removing_target': True,
#    'transaction_missing_in_test': [],
#    'transaction_extra_in_test': [],
#    'identity_columns_match_after_hyphen_normalization': True,
#    'selected_transaction_features_available_in_test': True,
#    'selected_identity_features_available_in_test': True},
#   'temporal_split_rows': {'train': 35000,
#    'calibration': 3750,
#    'threshold_selection': 3750,
#    'local_holdout_test': 7500},
#   'temporal_split_fraud_rates': {'train': 0.028657142857142857,
#    'calibration': 0.02666666666666667,
#    'threshold_selection': 0.0296,
#    'local_holdout_test': 0.019066666666666666}},
#  'business_cost_config': {'fp_cost': 10.0,
#   'fn_cost': 500.0,
#   'review_cost': 5.0,
#   'review_lower_bound': 0.3},
#  'shap_generated': {'summary': True,
#   'feature_importance': True,
#   'individual': True},
#  'runtime': {'python': '3.13.15',
#   'numpy': '2.5.2',
#   'pandas': '2.3.3',
#   'sklearn': '1.9.0',
#   'scipy': '1.18.1',
#   'lightgbm': '4.7.0',
#   'xgboost': '3.4.1',
#   'shap': '0.52.0',
#   'mlflow': '3.15.2',
#   'streamlit': '1.62.0'},
#  'note': 'All numeric metrics in this file were generated by this training run.'}
