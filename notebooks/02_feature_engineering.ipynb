# %% [markdown]
# # Feature Engineering\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
from src.data.loader import load_training_data

# %%
from src.features.feature_engineering import FraudFeatureEngineer

# %%
df=load_training_data(sample_size=10000)

# %%
X=df.drop(columns=['isFraud'])

# %%
fe=FraudFeatureEngineer().fit(X)

# %%
fe.transform(X.head()).head()
# Out:
#    TransactionDT  TransactionAmt ProductCD  card1  card2  card3       card4  \
# 0          86400            68.5         W  13926    NaN  150.0    discover
# 1          86401            29.0         W   2755  404.0  150.0  mastercard
# 2          86469            59.0         W   4663  490.0  150.0        visa
# 3          86499            50.0         W  18132  567.0  150.0  mastercard
# 4          86506            50.0         H   4497  514.0  150.0  mastercard
#
#    card5   card6  addr1  ...  card1_frequency  P_emaildomain_frequency  \
# 0  142.0  credit  315.0  ...           0.0001                   0.2105
# 1  102.0  credit  325.0  ...           0.0012                   0.3677
# 2  166.0   debit  330.0  ...           0.0021                   0.0084
# 3  117.0   debit  476.0  ...           0.0096                   0.1726
# 4  102.0  credit  420.0  ...           0.0001                   0.3677
#
#   DeviceInfo_frequency transaction_count_by_card  average_amount_by_card  \
# ...
