# %% [markdown]
# # Baseline Model\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
from src.models.train import train_project

# %%
metadata=train_project(model_names=['logistic'], sample_size=50000)
# Out:
# 2026-09-01 19:56:44,271 | INFO | src.models.train | Loading REAL IEEE-CIS training data (debug sample)
# 2026-09-01 19:56:47,789 | INFO | src.models.train | Training logistic
# c:\Users\alifh\Downloads\real-time-fraud-risk-platform-github-ready\real-time-fraud-risk-platform\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
metadata
# Out:
# {'model_name': 'logistic',
#  'model_version': 'logistic_v1',
#  'result_label': 'LOCAL IEEE-CIS HOLDOUT RESULTS',
#  'training_timestamp_utc': '2026-09-01T13:56:54.865532+00:00',
#  'selection_metric': 'validation_pr_auc',
#  'calibration_method': 'sigmoid',
#  'calibration_selection_brier_scores': {'identity': 0.17966940430048245,
#   'sigmoid': 0.017363605199502592,
#   'isotonic': 0.017636966518766662},
#  'threshold': 0.99,
#  'validation_metrics': {'pr_auc': 0.12254185985140398,
#   'roc_auc': 0.800115861946035,
#   'precision': 0.0,
#   'recall': 0.0,
#   'fraud_capture_rate': 0.0,
#   'f1': 0.0,
#   'false_positive_rate': 0.0,
#   'brier_score': 0.027536719565524555,
#   'threshold': 0.99,
#   'tn': 3639,
#   'fp': 0,
#   'fn': 111,
#   'tp': 0,
#   'fixed_fpr': 0.01,
#   'fixed_fpr_threshold': 0.21020477877043794,
#   'recall_at_fixed_fpr': 0.09009009009009009,
#   'precision_at_fixed_fpr': 0.2222222222222222,
#   'business_cost': 54095.0,
# ...
