# %% [markdown]
# # Model Evaluation\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
import pandas as pd

# %%
pd.read_csv('../reports/metrics/model_comparison.csv')
# Out:
#       model    pr_auc   roc_auc  precision    recall  fraud_capture_rate  \
# 0  lightgbm  0.346611  0.889028   0.857143  0.054054            0.054054
# 1   xgboost  0.351698  0.898289   0.700000  0.126126            0.126126
#
#          f1  false_positive_rate  brier_score  threshold  ...  tp  fixed_fpr  \
# 0  0.101695             0.000275     0.023141       0.67  ...   6       0.01
# 1  0.213740             0.001649     0.023309       0.48  ...  14       0.01
#
#    fixed_fpr_threshold  recall_at_fixed_fpr  precision_at_fixed_fpr  \
# 0             0.300545             0.270270                0.461538
# 1             0.271215             0.252252                0.444444
#
#    business_cost  train_seconds  calibration_method  fit_iterations  \
# 0        40800.0       1.930043             sigmoid             100
# 1        44700.0       2.094442             sigmoid              -1
#
#    converged_within_budget
# 0                    False
# 1                     True
#
# [2 rows x 23 columns]
