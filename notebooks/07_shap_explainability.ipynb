# %% [markdown]
# # SHAP Explainability\nBusiness logic is imported from `src/`; this notebook is a demonstration layer.

# %%
from pathlib import Path

# %%
from src.data.loader import load_training_data

# %%
from src.models.predict import load_artifacts

# %%
from src.explainability.shap_explainer import save_shap_summary

# %%
df=load_training_data(sample_size=10000).drop(columns=['isFraud'])

# %%
save_shap_summary(load_artifacts().model, df, Path('reports/figures/shap_summary.png'))
# Out:
# True
